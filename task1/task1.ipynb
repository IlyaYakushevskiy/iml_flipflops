# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaYakushevskiy/iml_flipflops/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -d -r  iml_flipflops/
# !git clone https://github.com/IlyaYakushevskiy/impl_flipflops #clones repository with all materials
# Out:
# rm: cannot remove 'impl_flipflops/': No such file or directory
# Cloning into 'impl_flipflops'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), 1.19 MiB | 3.63 MiB/s, done.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/impl_flipflops/train.csv")


X = df.iloc[:, 2:]
#W = np.random.rand(10000,1)
xtx = X.transpose() @ X #10 x 10
Y = df.iloc[:, 1:2 ] #10k x 1 
inv = np.linalg.inv(xtx) # 10 x 10 
inv.shape


#f[:]
#mean = np.mean([1.2,2])
#mean
# Out:
# (10, 10)

# %%
invx = inv @ X.transpose() # 10 x 10k
W = invx @ Y 
W
# Out:
#      y
# 0  0.1
# 1  0.1
# 2  0.1
# 3  0.1
# 4  0.1
# 5  0.1
# 6  0.1
# 7  0.1
# 8  0.1
# 9  0.1

# %%
#Y_fin = X @ W
print(X.shape, W.shape)
# Out:
# (10000, 10) (10, 1)

# %%
⁄X.shape
# Out:
# (10000, 10)

# %%
row = df.iloc[ 2, 2: ]

X @ W
# Out:
#   File "<ipython-input-28-01b2a8974ca1>", line 3
#     X @ W
#         ^
# SyntaxError: invalid character in identifier

# %%
X
# Out:
#                x1           x2           x3           x4           x5  \
# 0     1764.052346   400.157208   978.737984  2240.893199  1867.557990
# 1      144.043571  1454.273507   761.037725   121.675016   443.863233
# 2    -2552.989816   653.618595   864.436199  -742.165020  2269.754624
# 3      154.947426   378.162520  -887.785748 -1980.796468  -347.912149
# 4    -1048.552965 -1420.017937 -1706.270191  1950.775395  -509.652182
# ...           ...          ...          ...          ...          ...
# 9995   -30.453041  1082.680684  -530.579767   602.366643 -2138.290628
# 9996  2520.830358  -124.883939    18.067992  -998.622811 -1262.733524
# 9997  -545.704959  1696.765630  -508.186053     3.620563 -1018.514516
# 9998  -367.787118  -568.357801  -721.247794   198.279702  -217.422041
# 9999   428.570549  -164.999054   864.962658  -647.662456   720.057730
#
#                x6           x7           x8           x9          x10
# ...
